# %% [markdown]
# # Iteration 01 - Project Setup And Paper Extraction
#
# ## Aim
#
# Establish the project scaffold, identify the target recreation strategy, and capture the initial paper-to-model extraction.
#
# ## Prompt Aim
#
# Create a clean repository structure for an iterative recreation of the Monks et al. stroke pathway DES using Python 3.11 and SimPy 4.1.1.
#
# ## Notes
#
# - Record all subsequent prompts and generated code snippets in later iterations.
# - Add tests and tester notes as functionality is introduced.

# %% [markdown]
# ## Source Documents
#
# - `docs/source_text/assignment_brief.md`
# - `docs/source_text/Monks_et_al.md`
# - `docs/source_text/Monks_et_al_appendix.md`

# %%
from pathlib import Path

root = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
for rel in [
    'docs/paper_to_model_spec.md',
    'docs/assumptions.md',
    'src/stroke_sim/distributions.py',
]:
    path = root / rel
    print(rel, 'exists' if path.exists() else 'missing')

# %% [markdown]
# ## Tester Notes
#
# - Initial scaffold verified with passing smoke tests.
# - Iteration 02 should encode Figure 2 arrival rates, appendix LOS tables, and routing matrices.
